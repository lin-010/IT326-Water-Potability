# %%
# Phase 1: Data Collection & Exploration

# 1. Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 2. Load dataset
df = pd.read_csv("Raw_dataset.csv")   # dataset must be in the same folder or adjust path

# 3. Basic dataset info
print("Shape of dataset:", df.shape)
print("\nColumns:", df.columns)
print("\nData types:\n", df.dtypes)
print("\nFirst 5 rows:\n", df.head())

# 4. Check for missing values
print("\nMissing values per column:\n", df.isnull().sum())

# 5. Class balance (Potability distribution)
print("\nClass distribution:\n", df['Potability'].value_counts())

df['Potability'].value_counts().plot(kind='bar', title='Class Distribution (Potability)')
plt.show()

# 6. Descriptive statistics
print("\nStatistical summary:\n", df.describe())

# 7. Correlation matrix
plt.matshow(df.corr())
plt.colorbar()
plt.title("Correlation Heatmap", pad=20)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 9
#       6 import matplotlib.pyplot as plt
#       8 # 2. Load dataset
# ----> 9 df = pd.read_csv("Raw_dataset.csv")   # dataset must be in the same folder or adjust path
#      11 # 3. Basic dataset info
#      12 print("Shape of dataset:", df.shape)
#
# ...
